# %%
import boto3
import pdfplumber
import io
import csv
import re
import pandas as pd
from pdf2image import convert_from_bytes
import pytesseract

print("Starting")
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\mquig\AppData\Local\Programs\Tesseract-OCR\tesseract.exe"
#print(pytesseract.get_tesseract_version())

client = boto3.client('s3');

bucket_name = 'music-industry-data-lake'
obj_key = "raw/pollstar_dir/pdf/reports_pack/top-tours/2019/north-american/Top200NorthAmericanTours_791.pdf"

non_musician_tours = []
non_musicians_path = "../data_cleaning/non_musicians.txt"

with open(non_musicians_path, 'r') as file:
    for line in file:
        non_musician_tours.append(line.strip())

noisy_symbols = []
noisy_symbols_path = "../data_cleaning/noisy_symbols.txt"

with open(noisy_symbols_path, 'r') as file:
    for line in file:
        noisy_symbols.append(line.strip())

def extract_text_ocr(pdf_bytes, page_num):
    pdf_images = convert_from_bytes(
        pdf_bytes,
        first_page=page_num,
        last_page=page_num
    )

    texts = []
    
    for img in pdf_images:
        texts.append(pytesseract.image_to_string(img))

    return "\n".join(texts)

def clean_text(text):
    text = text.encode("latin1", errors="ignore").decode("utf-8", errors="ignore")

    for symbol in noisy_symbols:
        text = text.replace(symbol, "")

    text = text.strip()
    #text = re.sub(r"\s*", "\s", text)
    fields = text.split()
    text = " ".join(fields)
    
    return text

try:
    file = client.get_object(Bucket=bucket_name, Key=obj_key)
    pdf_bytes = file['Body'].read()
    pdf_file = io.BytesIO(pdf_bytes)

    with pdfplumber.open(pdf_file) as pdf:
        top_tours_musicians = []
        top_tours_all = []
        print(len(pdf.pages))

        for page_num, page in enumerate(pdf.pages, start=1):
            page_text = page.extract_text()

            if not page_text:
                page_text = extract_text_ocr(pdf_bytes, page_num)
                #print(page_text)

            if not page_text:
                print("Did not find text with pdfplumber or OCR. Skipping page.")
                continue
            
            lines = page_text.splitlines()

            for line in lines:
                        if re.search(r"^\d", line) and len(line) >= 40:
                            try:
                                line = clean_text(line)
                                print(line)
                                
                                tour_data = re.split(r"\s", line, 2);
                                rank = tour_data[0]
                                gross_millions = tour_data[1]
                                tour_data = tour_data[2]
        
                                end_of_artist_name_idx = re.search(r"\d*\.\d*", tour_data)
                                artist = tour_data[0:end_of_artist_name_idx.start()-2]
                                tour_data = tour_data[end_of_artist_name_idx.start():]

                                view_remaining_columns = re.split(r"\s", tour_data, 5)
        
                                if "/" in view_remaining_columns[4]:
                                    tour_data = re.split(r"\s", tour_data, 5)
                                    avg_ticket_price = tour_data[0]
                                    avg_num_tickets = tour_data[1]
                                    total_num_tickets = tour_data[2]
                                    avg_gross = tour_data[3]
                                    cities_shows = tour_data[4]
                                    agency = tour_data[5]

                                    tour_dict = {
                                        "Rank": rank,
                                        "Gross Millions": gross_millions,
                                        "Artist": artist,
                                        "Average Ticket Price": avg_ticket_price,
                                        "Average Tickets": avg_num_tickets,
                                        "Total Tickets": total_num_tickets,
                                        "Average Gross": avg_gross,
                                        "Cities Shows": cities_shows,
                                        "Agency": agency
                                    }
                                            
                                    #print(tour_dict)
            
                                    top_tours_all.append(tour_dict)

                                    if artist not in non_musicians:
                                        top_tours_musicians.append(tour_dict)
                            except Exception as e:
                                print("Error parsing tour record: ", e)

except client.exceptions.NoSuchKey:
    print(f"Error: Object '{object_key}' not found in bucket '{bucket_name}'")
    exit()
except Exception as e:
    print(f"Error retrieving object: {e}")
    exit()

'''
FOR: View files in bucket

bucket_name = "music-industry-data-lake"

resp = client.list_objects_v2(
    Bucket=bucket_name,
    Prefix="processed/pollstar_dir/reports_pack/musician-tours/"
)

for obj in resp.get("Contents", []):
    print(obj["Key"])
    response = client.delete_object(
        Bucket=bucket_name,
        Key=obj["Key"]
    )
'''
# Out:
# Starting
# 4
# 1 177.8 The Rolling Stones 226.61 49,041 784,652 11,112,923 14/16 Concerts West
# Error parsing tour record:  name 'non_musicians' is not defined
# 2 157.4 Elton John 36.25 14,266 1,155,510 1,943,702 57/81 The Howard Rose Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 3 97.0 Bob Seger & The Silver Bullet Band 111.72 12,224 867,925 1,365,694 1/71 ICM Partners
# Error parsing tour record:  name 'non_musicians' is not defined
# 4 87.8 Pink 40.76 14,867 624,419 2,092,626 37/42 Marshall Arts
# Error parsing tour record:  name 'non_musicians' is not defined
# 5 82.6 Ariana Grande 17.96 13,727 700,053 1,619,209 46/51 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 6 81.7 Jonas Brothers 106.14 14,246 769,310 1,512,119 48/54 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 7 81.6 KISS 01.94 11,945 800,302 1,217,650 67/67 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 8 77.5 Fleetwood Mac 42.42 13,607 544,286 1,937,462 10/13 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 9 76.1 Garth Brooks 88.09 65,846 856,000 5,853,250 9/12 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 10 75.6 Justin Timberlake 33.06 14,959 568,449 1,990,486 35/38 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 1 70.4 Billy Joel 30.07 25,770 541,166 3,351,790 21/21 Artist Group International
# Error parsing tour record:  name 'non_musicians' is not defined
# 12 68.6 Dead & Company 126.36 19,400 543,213 2,451,472 18/28 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 13 68.6 Eric Church 91.32 14,442 750,961 1,318,744 29/52 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 14 +667 Michael Bubl 18.58 11,711 562,115 1,388,689 46/48 Beaver Productions
# Error parsing tour record:  name 'non_musicians' is not defined
# 15 65.7 Trans-Siberian Orchestra 64.23 9,834 1,022,740 631,675 64/104 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 16 63.0 Backstreet Boys 96.67 9,871 651,515 954,244 51/66 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 17 60.3 Post Malone 19.85 13,598 503,135 1,629,712 31/37 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 18 59.6 Paul McCartney 158.44 23,517 376,264 3,725,863 15/16 Marshall Arts
# Error parsing tour record:  name 'non_musicians' is not defined
# 19 58.7 Celine Dion 67.99 7,762 349,295 1,303,991 15/45 CDA Productions
# Error parsing tour record:  name 'non_musicians' is not defined
# 20 2657.6 Cher 19.16 9,867 483,498 1,175,803 39/49 Marshall Arts
# Error parsing tour record:  name 'non_musicians' is not defined
# 21 53.5 Travis Scott 76.13 14,634 702,448 1,114,117 46/48 CLG - Cara Lewis Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 22 53.4 Jennifer Lopez 37.05 12,994 389,831 1,780,820 24/30 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 23 52.7 New Kids On The Block 80.76 11,889 655,643 960,176 53/55 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 24 51.9 Florida Georgia Line 70.54 16,008 736,377 1,129,244 42/46 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 25 487 Shawn Mendes 72.30 13,217 674,072 955,623 43/51 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 26 48.4 Lady Gaga 288.07 5,415 167,869 1,559,938 11/31 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 27 47.0 Dave Matthews Band 76.46 12,825 615,614 980,589 40/48 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 28 46.2 Mumford & Sons 72.11 13,923 640,453 1,003,973 42/46 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 29 45.8 Metallica 121.46 16,418 377,619 1,994,134 22/23 Artist Group International
# Error parsing tour record:  name 'non_musicians' is not defined
# 30 45.4 Queen + Adam Lambert 122.69 14,817 370,431 1,817,922 23/25 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 31 44.3 Thomas Rhett 66.58 13,571 664,970 903,574 48/49 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 32 44.2 Carrie Underwood 76.59 11,773 576,857 901,706 49/49 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 33 44.0 BTS 146.62 49,962 299,770 7,325,620 3/6 Big Hit Entertainment
# Error parsing tour record:  name 'non_musicians' is not defined
# 34 43.0 Zac Brown Band 60.91 15,015 705,721 914,542 40/47 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 35 42.2 Hootie & The Blowfish 64.43 14,200 653,201 914,878 44/46 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 36 6421 John Mayer 110.71 12,663 379,881 1,401,871 26/30 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 37 37.9 Andrea Bocelli 181.81 13,043 208,690 2,371,330 14/16 Klassics Music Management Limited
# Error parsing tour record:  name 'non_musicians' is not defined
# 38 37.2 Luke Bryan 57.93 16,902 642,284 979,171 36/38 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 39 36.9 Bad Bunny 90.42 11,662 408,160 1,054,459 33/35 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 40 36.9 Iron Maiden 72.45 13,404 509,368 971,093 34/38 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 41 36.0 Hugh Jackman 94.58 11,201 380,825 1,059,362 30/34 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 42 34.7 Phish 69.81 17,742 496,788 1,238,588 13/28 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 43 34.1 Aerosmith 207.93 4,828 164,150 1,003,853 12/34 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 44 33.6 George Strait 158.35 26,533 212,266 4,201,410 5/8 The Erv Woolsey Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 45 30.8 Chris Stapleton 73.81 12,655 417,618 934,129 33/33 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 46 29.5 Khalid 66.30 12,729 445,514 843,986 32/35 CLG - Cara Lewis Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 47 28.4 Tool 101.02 13,372 280,822 1,350,881 19/21 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 48 27.7 Chayanne 89.92 6,298 308,622 566,323 41/49 Chaf Enterprises
# Error parsing tour record:  name 'non_musicians' is not defined
# 49 26.7 JoJo Siwa 55.28 6,033 482,600 333,494 80/80 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 50 25.6 Mare Anthony 105.73 10,075 241,795 1,065,214 23/24 Cardenas Marketing Network
# Error parsing tour record:  name 'non_musicians' is not defined
# C:\Users\mquig\AppData\Local\Temp\ipykernel_9488\1073620215.py:89: DeprecationWarning: 'maxsplit' is passed as positional argument
#   tour_data = re.split(r"\s", line, 2);
# C:\Users\mquig\AppData\Local\Temp\ipykernel_9488\1073620215.py:98: DeprecationWarning: 'maxsplit' is passed as positional argument
#   view_remaining_columns = re.split(r"\s", tour_data, 5)
# C:\Users\mquig\AppData\Local\Temp\ipykernel_9488\1073620215.py:101: DeprecationWarning: 'maxsplit' is passed as positional argument
#   tour_data = re.split(r"\s", tour_data, 5)
# 101 11.4 Alan Jackson 71.76 8,795 158,312 631,132 18/18 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 102.-11.2 Hillsong United 37.17 7,333 300,634 272,582 39/41 Premier Productions
# Error parsing tour record:  name 'non_musicians' is not defined
# 103. 11.0 Old Dominion 48.85 4,707 225,940 229,931 48/48 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 104 10.8 James Taylor 90.60 7,913 118,699 716,917 15/15 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 105 610.7 Lizzo 45.03 3,777 237,934 170,052 48/63 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 106 10.7. Anuel AA 72.19 6,444 148,218 465,181 22/23 MN2S
# Error parsing tour record:  name 'non_musicians' is not defined
# 107. 10.6 For King & Country 36.51 4,100 291,065 149,675 71/71 Jeff Roberts & Associates
# Error parsing tour record:  name 'non_musicians' is not defined
# 109 10.4 s Bon Iver 60.37 5,939 172,229 358,532 26/29 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 10 10.1 Van Morrison 160.35 3,949 63,182 633,202 7/16 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 411 10.0 Lynyrd Skynyrd 67.29 7417 148,346 499,147 20/20 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 112 9.6 Mannheim Steamroller 62.83 1,827 153,431 114,766 74/84 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 113 9.6 Greta Van Fleet 48.79 5,171 196,481 252,293 28/38 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 114 9.5 Hozier 47.10 3,266 202,520 153,845 60/62 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 15 9.4 Mariah Carey 131.01 3,276 72,071 429,188 19/22 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 116 9.4 Anderson .Paak 62.47 5,127 179,448 269,015 35/35 Creative Artists Agency
# 117 9.4 Gloria Trevi 49.03 6,396 191,872 313,613 26/30 The Sixth House
# Error parsing tour record:  name 'non_musicians' is not defined
# 118 9.4 Casting Crowns 39.96 3,789 234,904 151,398 62/62 Jeff Roberts & Associates
# Error parsing tour record:  name 'non_musicians' is not defined
# 119 9.3 Lauren Daigle 50.56 3,696 184,795 186,870 48/50 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 120 9.2 Weezer / Pixies 52.87 7,912 174,058 418,295 22/22 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 121 9.2 Hits Deep Tour / TobyMac 36.24 6,857 253,715 248,503 34/37 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 122 9.1 Jim Gaffigan 60.15 3,235 152,036 194,585 24/47 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 123 91 The Chainsmokers 60.22 8,911 151,488 536,610 17/17 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 124 8.9 Alejandro Sanz 76.57 6,437 115,873 492,888 18/18 OCESA Seitrack
# Error parsing tour record:  name 'non_musicians' is not defined
# 125 8.8 Florence + The Machine 61.46 8,435 143,394 518,431 15/17 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 126 8.6 Roger Waters 101.80 12,110 84,773 1,232,823 3/7 Sensible Events
# Error parsing tour record:  name 'non_musicians' is not defined
# 127 8.5 Ron White 56.73 1,553 150,664 88,120 81/97 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 128 8.5 Chris Tomlin 37.95 3,714 222,824 140,948 56/60 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 129 8.4 The Tenderloins 63.67 5,103 132,677 324,931 22/26 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 130 8.3 J Balvin 66.57 7777 124,433 517,726 16/16 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 131 8.2 Childish Gambino 86.01 11,980 95,843 1,030,452 7/8 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 132 7.9 Derek Hough 68.10 2,160 116,654 147,119 54/54 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 133 7.8 Chicago 76.29 2,506 102,744 191,167 34/41 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 134 7.8 Sarah Brightman 82.44 2,766 94,059 228,052 34/34 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 135 77 Christina Aguilera 145.63 3,297 52,744 480,077 7/16 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 136 7.6 Frankie Valli And The Four Seasons 76.72 2,240 98,575 171,888 36/44 APA
# Error parsing tour record:  name 'non_musicians' is not defined
# 137 7.6 Barry Manilow 85.73 1,470 88,177 125,994 8/60 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 138 75 2Cellos 57.40 4,335 130,045 248,814 27/30 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 139 7.4 Willie Nelson 79.02 3,107 93,220 245,527 25/30 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 140 7.2 Ringo Starr & His All Starr Band 67.99 4,828 106,211 328,245 9/22 Powerline Entertainment
# Error parsing tour record:  name 'non_musicians' is not defined
# 141 7.0 Journey 139.37 4,584 50,429 638,916 2/11 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 142 7.0 Tyler, The Creator 51.92 7,923 134,691 411,350 6/17 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 143 6.9 Brandi Carlile 60.80 4,036 113,015 245,422 9/28 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 144 67 Casting Crowns / Hillsong Worship 44.20 11,694 152,027 516,877 13/13 Jeff Roberts & Ass. / Premier Prod.
# Error parsing tour record:  name 'non_musicians' is not defined
# 145 6.7 Joe Bonamassa 120.02 2,326 55,817 279,126 8/24 J&R Adventures
# Error parsing tour record:  name 'non_musicians' is not defined
# 146 6.6 Rain - A Tribute To The Beatles 51.64 1,498 127,318 77,355 65/85 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 147 6.5 John Crist 37.39 1,442 174,528 53,928 87/121 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 148 6.5 The 1975 47.56 6,500 136,510 309,140 9/21 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 149 6.5 Godsmack , 122,856 308,054 WME
# Error parsing tour record:  'NoneType' object has no attribute 'start'
# 151 6.4 Mana 127.70 12,600 50,401 1,609,096 4/4 Angelo Medina Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 152 6.2 Springsteen On Broadway 506.39 948 12,324 480,055 3/13 Thrill Hill Productions
# Error parsing tour record:  name 'non_musicians' is not defined
# 153 6.2 Cody Johnson 32.39 2,973 190,242 96,285 63/64 Red 11 Music
# Error parsing tour record:  name 'non_musicians' is not defined
# 154 6.1 Dierks Bentley 51.37 7,459 119,349 383,177 16/16 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 155 6.1 Heart 61.28 9,002 99,018 551,611 11/11 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 156 6.0 Juan Luis Guerra 116.00 7,435 52,042 862,417 7/7 Sony Music
# Error parsing tour record:  name 'non_musicians' is not defined
# 157 6.0 Tedeschi Trucks Band 65.94 3,048 91,447 200,988 17/30 Entourage Talent Assoc.
# Error parsing tour record:  name 'non_musicians' is not defined
# 158 6.0 Anita Baker 114.51 3,490 52,346 399,612 7/15 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 159 5.9 Winter Jam / Newsboys 21.52 6,373 274,023 137,170 43/43 Premier Productions
# Error parsing tour record:  name 'non_musicians' is not defined
# 160 5.9 Meek Mill 54.64 5,112 107,349 279,333 20/21 Celebrity Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 161 5.8 Santana 74.58 7,035 77,383 524,652 11/11 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 162 5.7 90's Pop Tour / OV7 36.43 17,515 157,637 638,149 9/9 BOBO
# Error parsing tour record:  name 'non_musicians' is not defined
# 163 5.6 Death Cab For Cutie 49.55 2,899 113,049 143,621 37/39 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 164 5.6 Il Divo 82.87 1,873 67,434 155,236 36/36 JEP Entertainment Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 165 5.5 Tame Impala 46.46 7,022 119,373 326,207 13/17 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 166 5.5 Roberto Carlos 108.97 4,595 50,545 500,718 11/11 DC Set Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 167 5.5 Mary J. Blige 77.41 7,096 70,958 549,288 10/10 APA
# 168 5.5 Widespread Panic 73.14 3,413 75,087 249,633 10/22 Progressive Global Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 169 5.5 The Piano Guys 63.26 2,476 86,676 156,661 34/35 CM Partners
# Error parsing tour record:  name 'non_musicians' is not defined
# 170 5.4 Why Dont We 48.67 3,973 111,257 193,395 28/28 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 171 5.2 Billie Eilish 65.25 8,923 80,310 582,261 9/9 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 172 5.2 Bert Kreischer 47.08 1,634 111,100 76,914 43/68 United Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 173 5.1 Peter Frampton 73.65 5,818 69,818 428,528 12/12 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 174 54 The Temptations / The Four Tops 62.08 1,859 81,783 115,383 44/44 CM Partners
# Error parsing tour record:  name 'non_musicians' is not defined
# 175 5.0 Cody Jinks 55.12 2,408 91,522 132,766 34/38 tue Grit Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 176 5.0 Mark Knopfler 98.90 4,613 50,738 456,162 10/11 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 177 5.0 Arijit Singh 98.35 6,366 50,925 626,084 8/8 Tarsame Mittal Talent Management
# Error parsing tour record:  name 'non_musicians' is not defined
# 178 4.9 Eric Clapton 188.29 13,084 26,168 2,463,644 2/2 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 179 49 Earth, Wind & Fire 76.08 2,943 64,736 223,855 15/22 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 180 49 Odesza 60.39 13,543 81,256 817,850 4/6 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 181 4.9 Ozuna 105.16 11,654 46,615 1,225,545 4/4 Saavedra Booking
# Error parsing tour record:  name 'non_musicians' is not defined
# 182 48 Camila / Sin Bandera 59.50 5,389 80,828 320,596 16/15 APA
# Error parsing tour record:  name 'non_musicians' is not defined
# 183 48 Nine Inch Nails 88.79 4,124 53,611 366,165 4/13 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 184 47 Kevin Hart 80.27 9,831 58,986 789,111 5/6 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 185 47 Michael Franti & Spearhead 55.09 2,040 85,690 112,402 35/42 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 186 47 John Legend 108.61 3,582 42,981 389,018 10/12 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 187 4.6 Snoop Dogg 60.02 5,937 77,186 356,366 13/13 Universal Attractions Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 188 46 Jo Koy 50.12 1,965 92,356 98,491 33/47 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 189 4.6 Suicideboy$ 50.16 3,817 91,615 91,468 24/24 Paradigm Talent Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 190 4.6 Los Angeles Azules 48.65 5,234 94,209 254,609 18/18 M&M Group
# Error parsing tour record:  name 'non_musicians' is not defined
# 191 45 Young The Giant / Fitz & The Tantrums 38.89 4,322 116,686 168,062 27/27 Paradigm Talent Agency / WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 192 4.5 Lindsey Stirling 62.55 3,186 86,021 67,420 27/27 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 193 4.4 Straight No Chaser 51.57 2,048 86,004 05,591 35/42 ICM Partners
# Error parsing tour record:  name 'non_musicians' is not defined
# 194 4.4 Five Finger Death Punch / Breaking Benjamin 59.00 6,174 74,091 364,280 12/12 AGI / CAA
# Error parsing tour record:  name 'non_musicians' is not defined
# 195 4.3 Robyn 72.07 4,638 60,290 334,230 12/13 Pinnacle Entertainment
# Error parsing tour record:  name 'non_musicians' is not defined
# 196 4.3 Rob Thomas 75.05 2,199 57,180 65,057 23/26 Creative Artists Agency
# Error parsing tour record:  name 'non_musicians' is not defined
# 197 4.3 Tom Segura 42.96 2,081 99,873 89,376 31/48 WME
# Error parsing tour record:  name 'non_musicians' is not defined
# 198 4.3 Got7 112.34 6,337 38,023 711,890 6/6 JYP Entertainment
# Error parsing tour record:  name 'non_musicians' is not defined
# '\nFOR: View files in bucket\n\nbucket_name = "music-industry-data-lake"\n\nresp = client.list_objects_v2(\n    Bucket=bucket_name,\n    Prefix="processed/pollstar/reports/musician-tours/"\n)\n\nfor obj in resp.get("Contents", []):\n    print(obj["Key"])\n    response = client.delete_object(\n        Bucket=bucket_name,\n        Key=obj["Key"]\n    )\n'
